# %% [markdown]
# # ***Analysis on super store***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Read the file

# %%
df = pd.read_excel(r"C:\Users\Admin\Desktop\Practice\superstore.xls")

# %%
df
# Out:
#       Row ID        Order ID Order_Date  Ship Date       Ship Mode  \
# 0          1  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 1          2  CA-2018-152156 2018-11-08 2018-11-11    Second Class
# 2          3  CA-2018-138688 2018-06-12 2018-06-16    Second Class
# 3          4  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# 4          5  US-2017-108966 2017-10-11 2017-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country/Region             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# ### Find the number of col and rows in the dataset

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# ### Dimension of the dataset

# %%
df.ndim

# %% [markdown]
# ### Getting the Statistical information of the dataset

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ### Total number of column in the Dataset

# %%
count_col  = df.columns
count_col = pd.Series(count_col)
count_col
# Out:
# 0             Row ID
# 1           Order ID
# 2         Order_Date
# 3          Ship Date
# 4          Ship Mode
# 5        Customer ID
# 6      Customer Name
# 7            Segment
# 8     Country/Region
# 9               City
# 10             State
# 11       Postal Code
# 12            Region
# 13        Product ID
# 14          Category
# 15      Sub-Category
# 16      Product Name
# 17             Sales
# 18          Quantity
# 19          Discount
# 20            Profit
# dtype: object

# %% [markdown]
# ### Checling the nul values

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order_Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# dtype: int64

# %% [markdown]
# ### Getting the datypes in the dataset

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order_Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# Country/Region            object
# City                      object
# State                     object
# Postal Code              float64
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# dtype: object

# %% [markdown]
# ### Getting the whole information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order_Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %% [markdown]
# ### Renaming the colname and getting the top 5 records

# %%
df.rename(columns = {'Country/Region' : 'Country' } , inplace = True)
df.head()
# Out:
#    Row ID        Order ID Order_Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Bottom 5 records

# %%
df.tail()
# Out:
#       Row ID        Order ID Order_Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2016-110422 2016-01-21 2016-01-23    Second Class
# 9990    9991  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9991    9992  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9992    9993  CA-2019-121258 2019-02-26 2019-03-03  Standard Class
# 9993    9994  CA-2019-119914 2019-05-04 2019-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
consumer = df.loc[: , ['Customer Name' , 'Country','City' , 'Product Name' , 'Quantity' , 'Sales' , 'Profit']]
consumer
# Out:
#          Customer Name        Country             City  \
# 0          Claire Gute  United States        Henderson
# 1          Claire Gute  United States        Henderson
# 2      Darrin Van Huff  United States      Los Angeles
# 3       Sean O'Donnell  United States  Fort Lauderdale
# 4       Sean O'Donnell  United States  Fort Lauderdale
# ...                ...            ...              ...
# 9989  Tom Boeckenhauer  United States            Miami
# 9990       Dave Brooks  United States       Costa Mesa
# 9991       Dave Brooks  United States       Costa Mesa
# 9992       Dave Brooks  United States       Costa Mesa
# 9993      Chris Cortes  United States      Westminster
#
#                                            Product Name  Quantity     Sales  \
# 0                     Bush Somerset Collection Bookcase         2  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...         3  731.9400
# ...

# %%
consumer1 = consumer.loc[(consumer['Profit'] > 100) & (consumer['Sales']>=200.786) & (consumer['Country']== 'United States')]
consumer1.max()
# Out:
# Customer Name                    Zuschuss Donatelli
# Country                               United States
# City                                        Yonkers
# Product Name     netTALK DUO VoIP Telephone Service
# Quantity                                         14
# Sales                                       17499.9
# Profit                                      8399.98
# dtype: object

# %%
prod = df.loc[: , ['Product Name' , 'Sales' , 'Profit' , 'Region']]
prod
# Out:
#                                            Product Name     Sales    Profit  \
# 0                     Bush Somerset Collection Bookcase  261.9600   41.9136
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400  219.5820
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200    6.8714
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775 -383.0310
# 4                        Eldon Fold 'N Roll Cart System   22.3680    2.5164
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480    4.1028
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600   15.6332
# 9991                              Aastra 57i VoIP phone  258.5760   19.3932
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000   13.3200
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600   72.9480
#
#      Region
# 0     South
# 1     South
# 2      West
# ...

# %%
sns.catplot(x = 'Sales' , y = 'Profit' , hue = 'Region' , data = prod , kind = 'violin' )

# %%
prod.sum()
# Out:
# Product Name    Bush Somerset Collection BookcaseHon Deluxe Fa...
# Sales                                                  2.2972e+06
# Profit                                                     286397
# Region          SouthSouthWestSouthSouthWestWestWestWestWestWe...
# dtype: object
